# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("/content/Car_sales.csv")
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
table=pd.pivot_table(df,values="Sales_in_thousands",index="Vehicle_type",columns="Model",aggfunc=np.sum)
table
# Out:
# <ipython-input-6-01957cd45616>:1: FutureWarning: The provided callable <function sum at 0x7e0d12312dd0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=pd.pivot_table(df,values="Sales_in_thousands",index="Vehicle_type",columns="Model",aggfunc=np.sum)
# Model          3-Sep  3000GT    300M    323i   328i  4Runner  5-Sep    528i  \
# Vehicle_type
# Car              NaN     NaN     NaN     NaN    NaN   68.411    NaN     NaN
# Passenger     12.115    0.11  30.696  19.747  9.231      NaN  9.191  17.527
#
# Model             A4     A6  ...  Town & Country  Town car    V40     V70  \
# Vehicle_type                 ...
# Car              NaN    NaN  ...           53.48       NaN    NaN     NaN
# Passenger     20.397  18.78  ...             NaN    48.911  3.545  17.531
#
# Model         Villager  Viper  Voyager  Windstar  Wrangler  Xterra
# Vehicle_type
# ...

# %%
table=pd.pivot_table(df,values="Price_in_thousands",index="Manufacturer",columns="Model",aggfunc=np.mean)
table
# Out:
# <ipython-input-7-2668222c4fc6>:1: FutureWarning: The provided callable <function mean at 0x7e0d12313d00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table=pd.pivot_table(df,values="Price_in_thousands",index="Manufacturer",columns="Model",aggfunc=np.mean)
# Model         3-Sep  3000GT    300M   323i  328i  4Runner  5-Sep  528i     A4  \
# Manufacturer
# Acura           NaN     NaN     NaN    NaN   NaN      NaN    NaN   NaN    NaN
# Audi            NaN     NaN     NaN    NaN   NaN      NaN    NaN   NaN  23.99
# BMW             NaN     NaN     NaN  26.99  33.4      NaN    NaN  38.9    NaN
# Buick           NaN     NaN     NaN    NaN   NaN      NaN    NaN   NaN    NaN
# Cadillac        NaN     NaN     NaN    NaN   NaN      NaN    NaN   NaN    NaN
# Chevrolet       NaN     NaN     NaN    NaN   NaN      NaN    NaN   NaN    NaN
# ...

# %%
table=pd.pivot_table(df,values="Price_in_thousands",index="Vehicle_type",columns="Model",aggfunc=np.mean)
table
# Out:
# <ipython-input-10-b650f91b5b14>:1: FutureWarning: The provided callable <function mean at 0x7e0d12313d00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table=pd.pivot_table(df,values="Price_in_thousands",index="Vehicle_type",columns="Model",aggfunc=np.mean)
# Model         3-Sep  3000GT    300M   323i  328i  4Runner  5-Sep  528i     A4  \
# Vehicle_type
# Car             NaN     NaN     NaN    NaN   NaN   22.288    NaN   NaN    NaN
# Passenger      26.1   25.45  29.185  26.99  33.4      NaN  33.12  38.9  23.99
#
# Model            A6  ...  Taurus  Town car   V40   V70  Villager   Viper  \
# Vehicle_type         ...
# Car             NaN  ...     NaN       NaN   NaN   NaN     22.51     NaN
# Passenger     33.95  ...  17.885     43.33  24.4  28.8       NaN  69.725
#
# Model         Voyager  Windstar  Wrangler  Xterra
# Vehicle_type
# ...

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
table=pd.pivot_table(df,values="Sales_in_thousands",index="Vehicle_type",columns="Model",aggfunc=np.mean)
table
# Out:
# <ipython-input-17-89a47c25b853>:1: FutureWarning: The provided callable <function mean at 0x7e0d12313d00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table=pd.pivot_table(df,values="Sales_in_thousands",index="Vehicle_type",columns="Model",aggfunc=np.mean)
# Model          3-Sep  3000GT    300M    323i   328i  4Runner  5-Sep    528i  \
# Vehicle_type
# Car              NaN     NaN     NaN     NaN    NaN   68.411    NaN     NaN
# Passenger     12.115    0.11  30.696  19.747  9.231      NaN  9.191  17.527
#
# Model             A4     A6  ...  Town & Country  Town car    V40     V70  \
# Vehicle_type                 ...
# Car              NaN    NaN  ...           53.48       NaN    NaN     NaN
# Passenger     20.397  18.78  ...             NaN    48.911  3.545  17.531
#
# Model         Villager  Viper  Voyager  Windstar  Wrangler  Xterra
# Vehicle_type
# ...

# %%
table=pd.pivot_table(df,values=["Sales_in_thousands","Price_in_thousands"],index="Vehicle_type",columns=["Manufacturer","Horsepower"],aggfunc=[np.sum,np.mean])
table
# Out:
# <ipython-input-19-972e9a2784f7>:1: FutureWarning: The provided callable <function sum at 0x7e0d12312dd0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   table=pd.pivot_table(df,values=["Sales_in_thousands","Price_in_thousands"],index="Vehicle_type",columns=["Manufacturer","Horsepower"],aggfunc=[np.sum,np.mean])
# <ipython-input-19-972e9a2784f7>:1: FutureWarning: The provided callable <function mean at 0x7e0d12313d00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   table=pd.pivot_table(df,values=["Sales_in_thousands","Price_in_thousands"],index="Vehicle_type",columns=["Manufacturer","Horsepower"],aggfunc=[np.sum,np.mean])
#                             sum                                               \
# ...
